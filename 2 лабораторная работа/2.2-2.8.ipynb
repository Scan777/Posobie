# %%
# Установка библиотеки ultralytics
# !pip install ultralytics

# Установка библиотеки supervision для работы с видеопотоком
# !pip install supervision

# Проверка версии
import ultralytics
ultralytics.checks()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="ВАШ_API_КЛЮЧ")
project = rf.workspace("НАЗВАНИЕ_ВОРКСПЕЙСА").project("НАЗВАНИЕ_ПРОЕКТА")
dataset = project.version(ВЕРСИЯ).download("yolov8")

# %%
# !yolo task=(detect, classify, segment) mode=(train, predict, val) model=(yolov8n.pt, yolov8n-cls.pt, yolov8n-seg.pt) args

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'

# %%
# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=100 imgsz=640 batch=16

# %%
# !yolo task=detect mode=val model=runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %% [markdown]
# Файл с весами лучшей модели находится по пути:
# runs/detect/train/weights/best.pt
